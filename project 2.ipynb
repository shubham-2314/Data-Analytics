# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")

# %%
hb=pd.read_csv("headbrain.csv")
hb
# Out:
#      Gender  AgeRange  HeadSize  BrainWeight
# 0         1         1      4512         1530
# 1         1         1      3738         1297
# 2         1         1      4261         1335
# 3         1         1      3777         1282
# 4         1         1      4177         1590
# 5         1         1      3585         1300
# 6         1         1      3785         1400
# 7         1         1      3559         1255
# 8         1         1      3613         1355
# 9         1         1      3982         1375
# 10        1         1      3443         1340
# 11        1         1      3993         1380
# 12        1         1      3640         1355
# 13        1         1      4208         1522
# 14        1         1      3832         1208
# 15        1         1      3876         1405
# 16        1         1      3497         1358
# 17        1         1      3466         1292
# 18        1         1      3095         1340
# 19        1         1      4424         1400
# ...

# %%
hb.head()
# Out:
#    Gender  AgeRange  HeadSize  BrainWeight
# 0       1         1      4512         1530
# 1       1         1      3738         1297
# 2       1         1      4261         1335
# 3       1         1      3777         1282
# 4       1         1      4177         1590

# %%
hb.tail()
# Out:
#      Gender  AgeRange  HeadSize  BrainWeight
# 232       2         2      3214         1110
# 233       2         2      3394         1215
# 234       2         2      3233         1104
# 235       2         2      3352         1170
# 236       2         2      3391         1120

# %%
df=pd.DataFrame(data=hb)
df
# Out:
#      Gender  AgeRange  HeadSize  BrainWeight
# 0         1         1      4512         1530
# 1         1         1      3738         1297
# 2         1         1      4261         1335
# 3         1         1      3777         1282
# 4         1         1      4177         1590
# 5         1         1      3585         1300
# 6         1         1      3785         1400
# 7         1         1      3559         1255
# 8         1         1      3613         1355
# 9         1         1      3982         1375
# 10        1         1      3443         1340
# 11        1         1      3993         1380
# 12        1         1      3640         1355
# 13        1         1      4208         1522
# 14        1         1      3832         1208
# 15        1         1      3876         1405
# 16        1         1      3497         1358
# 17        1         1      3466         1292
# 18        1         1      3095         1340
# 19        1         1      4424         1400
# ...

# %%
df.shape
# Out:
# (237, 4)

# %%
df.dtypes
# Out:
# Gender         int64
# AgeRange       int64
# HeadSize       int64
# BrainWeight    int64
# dtype: object

# %%
df.describe()
# Out:
#            Gender    AgeRange     HeadSize  BrainWeight
# count  237.000000  237.000000   237.000000   237.000000
# mean     1.434599    1.535865  3633.991561  1282.873418
# std      0.496753    0.499768   365.261422   120.340446
# min      1.000000    1.000000  2720.000000   955.000000
# 25%      1.000000    1.000000  3389.000000  1207.000000
# 50%      1.000000    2.000000  3614.000000  1280.000000
# 75%      2.000000    2.000000  3876.000000  1350.000000
# max      2.000000    2.000000  4747.000000  1635.000000

# %%
df.isnull().sum()
# Out:
# Gender         0
# AgeRange       0
# HeadSize       0
# BrainWeight    0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.head()
# Out:
#    Gender  AgeRange  HeadSize  BrainWeight
# 0       1         1      4512         1530
# 1       1         1      3738         1297
# 2       1         1      4261         1335
# 3       1         1      3777         1282
# 4       1         1      4177         1590

# %%
df["HeadSize"].plot.box()

# %%
df["BrainWeight"].plot.box()

# %%
from scipy.stats import zscore
z=np.abs(zscore(hb))
z
# Out:
# array([[0.8767307 , 1.07449777, 2.40886829, 2.0579083 ],
#        [0.8767307 , 1.07449777, 0.28535333, 0.11763692],
#        [0.8767307 , 1.07449777, 1.72023489, 0.43407603],
#        [0.8767307 , 1.07449777, 0.39235214, 0.00727325],
#        [0.8767307 , 1.07449777, 1.4897759 , 2.557549  ],
#        [0.8767307 , 1.07449777, 0.13441126, 0.14261896],
#        [0.8767307 , 1.07449777, 0.41430062, 0.97535345],
#        [0.8767307 , 1.07449777, 0.2057438 , 0.23211156],
#        [0.8767307 , 1.07449777, 0.05759159, 0.60062293],
#        [0.8767307 , 1.07449777, 0.95478182, 0.76716983],
#        [0.8767307 , 1.07449777, 0.52399669, 0.47571276],
#        [0.8767307 , 1.07449777, 0.98496097, 0.80880656],
#        [0.8767307 , 1.07449777, 0.01648451, 0.60062293],
#        [0.8767307 , 1.07449777, 1.57482624, 1.99128954],
#        [0.8767307 , 1.07449777, 0.54324791, 0.62349678],
#        [0.8767307 , 1.07449777, 0.66396452, 1.01699018],
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([24], dtype=int64), array([2], dtype=int64))

# %%
plt.scatter(hb["HeadSize"],hb["BrainWeight"])
plt.show()

# %%
hb_new=hb[(z<3).all(axis=1)]

# %%
hb_new
# Out:
#      Gender  AgeRange  HeadSize  BrainWeight
# 0         1         1      4512         1530
# 1         1         1      3738         1297
# 2         1         1      4261         1335
# 3         1         1      3777         1282
# 4         1         1      4177         1590
# 5         1         1      3585         1300
# 6         1         1      3785         1400
# 7         1         1      3559         1255
# 8         1         1      3613         1355
# 9         1         1      3982         1375
# 10        1         1      3443         1340
# 11        1         1      3993         1380
# 12        1         1      3640         1355
# 13        1         1      4208         1522
# 14        1         1      3832         1208
# 15        1         1      3876         1405
# 16        1         1      3497         1358
# 17        1         1      3466         1292
# 18        1         1      3095         1340
# 19        1         1      4424         1400
# ...

# %%
hb_new["HeadSize"].plot.box()

# %%
hb_new["BrainWeight"].plot.box()

# %%
hb.shape
# Out:
# (237, 4)

# %%
hb_new.shape
# Out:
# (236, 4)

# %%
x=hb_new.iloc[:,2].values
x
# Out:
# array([4512, 3738, 4261, 3777, 4177, 3585, 3785, 3559, 3613, 3982, 3443,
#        3993, 3640, 4208, 3832, 3876, 3497, 3466, 3095, 4424, 3878, 4046,
#        3804, 3710, 4423, 4036, 4022, 3454, 4175, 3787, 3796, 4103, 4161,
#        4158, 3814, 3527, 3748, 3334, 3492, 3962, 3505, 4315, 3804, 3863,
#        4034, 4308, 3165, 3641, 3644, 3891, 3793, 4270, 4063, 4012, 3458,
#        3890, 4166, 3935, 3669, 3866, 3393, 4442, 4253, 3727, 3329, 3415,
#        3372, 4430, 4381, 4008, 3858, 4121, 4057, 3824, 3394, 3558, 3362,
#        3930, 3835, 3830, 3856, 3249, 3577, 3933, 3850, 3309, 3406, 3506,
#        3907, 4160, 3318, 3662, 3899, 3700, 3779, 3473, 3490, 3654, 3478,
#        3495, 3834, 3876, 3661, 3618, 3648, 4032, 3399, 3916, 4430, 3695,
#        3524, 3571, 3594, 3383, 3499, 3589, 3900, 4114, 3937, 3399, 4200,
#        4488, 3614, 4051, 3782, 3391, 3124, 4053, 3582, 3666, 3532, 4046,
#        3667, 2857, 3436, 3791, 3302, 3104, 3171, 3572, 3530, 3175, 3438,
# ...

# %%
x=x.reshape(-1,1)

# %%
y=hb_new.iloc[:,-1].values

# %%
y=y.reshape(-1,1)

# %%
x
# Out:
# array([[4512],
#        [3738],
#        [4261],
#        [3777],
#        [4177],
#        [3585],
#        [3785],
#        [3559],
#        [3613],
#        [3982],
#        [3443],
#        [3993],
#        [3640],
#        [4208],
#        [3832],
#        [3876],
#        [3497],
#        [3466],
#        [3095],
#        [4424],
#        [3878],
#        [4046],
#        [3804],
#        [3710],
#        [4423],
#        [4036],
#        [4022],
#        [3454],
#        [4175],
#        [3787],
#        [3796],
#        [4103],
#        [4161],
#        [4158],
#        [3814],
#        [3527],
#        [3748],
#        [3334],
#        [3492],
#        [3962],
#        [3505],
#        [4315],
#        [3804],
#        [3863],
#        [4034],
#        [4308],
#        [3165],
#        [3641],
#        [3644],
#        [3891],
#        [3793],
#        [4270],
#        [4063],
#        [4012],
#        [3458],
#        [3890],
#        [4166],
#        [3935],
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=50)

# %%
x_train.shape
# Out:
# (184, 1)

# %%
x_test.shape
# Out:
# (52, 1)

# %%
y_train.shape
# Out:
# (184, 1)

# %%
y_test.shape
# Out:
# (52, 1)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x.shape
# Out:
# (236, 1)

# %%
y.shape
# Out:
# (236, 1)

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([[0.26221142]])

# %%
lm.intercept_
# Out:
# array([330.03635294])

# %%
lm.score(x_train,y_train)
# Out:
# 0.6334601273239315

# %%
pred=lm.predict(x_test)
print("predicted result BrainWeight",pred)
print("actual BrainWeight",y_test)
# Out:
# predicted result BrainWeight [[1249.0873883 ]
#  [1324.07985509]
#  [1256.42930813]
#  [1278.71727903]
#  [1489.79747402]
#  [1158.10002474]
#  [1246.46527408]
#  [1210.54230921]
#  [1335.35494625]
#  [1346.89224884]
#  [1219.98192042]
#  [1219.98192042]
#  [1245.67863981]
#  [1392.77924775]
#  [1246.98969692]
#  [1330.11071781]
#  [1164.13088746]
#  [1296.80986717]
#  [1267.96661071]
#  [1221.81740037]
#  [1217.09759477]
#  [1245.15421696]
#  [1100.67572325]
#  [1310.18264971]
#  [1141.58070513]
#  [1231.519223  ]
#  [1255.64267386]
#  [1420.83586994]
#  [1506.84121647]
#  [1157.5756019 ]
#  [1211.5911549 ]
#  [1346.36782599]
#  [1302.84072988]
#  [1368.91800832]
#  [1221.29297753]
#  [1390.94376779]
#  [1388.32165357]
#  [1289.99237019]
#  [1307.29832406]
#  [1043.25142175]
#  [1277.66843334]
#  [1266.39334218]
#  [1193.23635534]
#  [1277.40622191]
#  [1181.96126418]
#  [1352.66090013]
#  [1356.85628289]
#  [1392.25482491]
#  [1284.48593032]
#  [1176.45482431]
#  [1211.06673206]
# ...

# %%
print("error:")
print(mean_squared_error(y_test,pred))
# Out:
# error:
# 5451.39076482303

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.5970539523941596

# %%
t=np.array([3802])
tn=t.reshape(-1,1)

# %%
lm.predict(tn)
# Out:
# array([[1326.96418074]])

# %%
def linreg():
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    print(lm.score(x_train,y_train))
    print(r2_score(y_test,pred))
    print(mean_squared_error(y_test,pred))

# %%
linreg()
# Out:
# 0.6334601273239315
# 0.5970539523941596
# 5451.39076482303

# %%
from sklearn.externals import joblib
joblib.dump(linreg,"lrsave")
# Out:
# ['lrsave']

# %%
import pickle
s=pickle.dumps(linreg)
clf2=pickle.loads(s)

# %%
clf2
# Out:
# <function __main__.linreg()>
