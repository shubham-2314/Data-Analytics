# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")

# %%
abalone=pd.read_csv("abalone.csv")

# %%
abalone
# Out:
#      Sex  Length  Diam  Height  Whole  Shucked  Viscera  Shell  Rings
# 0      M      91    73      19  102.8     44.9     20.2   30.0     15
# 1      M      70    53      18   45.1     19.9      9.7   14.0      7
# 2      F     106    84      27  135.4     51.3     28.3   42.0      9
# 3      M      88    73      25  103.2     43.1     22.8   31.0     10
# 4      I      66    51      16   41.0     17.9      7.9   11.0      7
# 5      I      85    60      19   70.3     28.2     15.5   24.0      8
# 6      F     106    83      30  155.5     47.4     28.3   66.0     20
# 7      F     109    85      25  153.6     58.8     29.9   52.0     16
# 8      M      95    74      25  101.9     43.3     22.5   33.0      9
# 9      F     110    88      30  178.9     62.9     30.2   64.0     19
# 10     F     105    76      28  121.3     38.8     29.5   42.0     14
# 11     M      86    70      22   81.2     33.5     16.2   27.0     10
# 12     M      98    76      27  108.3     43.5     19.0   38.0     11
# 13     F     107    81      29  136.9     54.5     34.2   41.0     10
# 14     F      94    71      20   95.1     33.5     16.1   37.0     10
# 15     M     100    80      26  132.9     51.6     26.6   48.0     12
# 16     I      71    56      17   58.1     19.0      7.9   23.0      7
# 17     F      88    68      20   90.2     37.6     17.4   26.0     10
# 18     M      73    59      16   51.1     19.4      8.6   20.0      7
# 19     M      90    64      20   76.2     34.1     15.0   23.0      9
# 20     M      71    56      19   49.1     19.1     12.4   15.0     11
# 21     I      76    55      20   45.1     16.0      9.8   17.0     10
# 22     F     113    88      31  187.9     85.5     42.8   54.0     12
# 23     F     110    83      27  152.7     63.6     42.0   40.0      9
# 24     F     123    96      33  232.3    102.6     60.2   61.0     10
# 25     F     112    88      28  185.7     76.5     37.6   60.0     11
# 26     F     116    90      37  199.1     78.9     54.4   57.0     11
# 27     M     118    89      28  186.2     71.2     46.8   56.0     12
# 28     M     121    95      36  187.3     78.8     43.8   59.0     15
# 29     M     115    85      28  172.7     78.6     45.4   40.0     11
# ...   ..     ...   ...     ...    ...      ...      ...    ...    ...
# 4147   M     139   110      39  332.9    145.4     72.0   89.0     11
# 4148   M     154   121      35  410.1    160.1    105.2   71.0     11
# 4149   I      56    43      14   24.8     12.6      4.3    6.0      6
# 4150   I      66    46      16   28.0     11.3      7.3    9.2      7
# 4151   I      70    50      15   33.9     16.7      7.1    8.2      6
# 4152   I      74    56      18   43.6     19.9     10.9   12.3      7
# 4153   I      86    63      23   76.8     37.7     14.3   22.0      8
# 4154   I      87    66      19   78.6     43.8     15.0   17.7      6
# 4155   I      88    70      22   76.1     31.5     17.9   23.0      6
# 4156   M      95    74      22   97.9     43.7     21.4   29.2      8
# 4157   M      95    72      28  102.7     48.2     20.9   31.0      8
# 4158   I      96    71      22   89.9     40.2     17.8   28.0      8
# 4159   F     112    88      27  160.5     70.0     32.3   51.8      9
# 4160   F     117    95      33  210.6     91.6     43.4   60.0     11
# 4161   F     117    91      34  198.9     85.1     52.6   56.9     11
# 4162   M      77    51      20   63.5     27.4     13.6   18.4      8
# 4163   I      78    62      17   68.8     36.2     13.9   15.8      7
# 4164   I      78    58      20   56.9     25.1     12.7   16.2      7
# 4165   I      81    60      17   60.7     30.0     10.1   17.6      7
# 4166   I      95    73      23   99.8     46.4     17.7   31.2     10
# 4167   M     100    76      25  115.4     53.8     25.3   30.7      9
# 4168   F     103    80      25  123.0     57.3     24.6   35.3      8
# 4169   M     104    77      33  158.2     75.0     36.0   36.3     10
# 4170   M     110    86      26  167.9     63.1     39.1   48.1     10
# 4171   M     112    86      31  173.5     80.0     34.4   45.8      8
# 4172   F     113    90      33  177.4     74.0     47.8   49.8     11
# 4173   M     118    88      27  193.2     87.8     42.9   52.1     10
# 4174   M     120    95      41  235.2    105.1     57.5   61.6      9
# 4175   F     125    97      30  218.9    106.2     52.2   59.2     10
# 4176   M     142   111      39  389.7    189.1     75.3   99.0     12
#
# [4177 rows x 9 columns]

# %%
df=pd.DataFrame(data=abalone)

# %%
df.head()
# Out:
#   Sex  Length  Diam  Height  Whole  Shucked  Viscera  Shell  Rings
# 0   M      91    73      19  102.8     44.9     20.2   30.0     15
# 1   M      70    53      18   45.1     19.9      9.7   14.0      7
# 2   F     106    84      27  135.4     51.3     28.3   42.0      9
# 3   M      88    73      25  103.2     43.1     22.8   31.0     10
# 4   I      66    51      16   41.0     17.9      7.9   11.0      7

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.dtypes
# Out:
# Sex         object
# Length       int64
# Diam         int64
# Height       int64
# Whole      float64
# Shucked    float64
# Viscera    float64
# Shell      float64
# Rings        int64
# dtype: object

# %%
df.describe()
# Out:
#             Length         Diam       Height        Whole      Shucked  \
# count  4177.000000  4177.000000  4177.000000  4177.000000  4177.000000
# mean    104.798420    81.576251    27.903280   165.748432    71.873498
# std      24.018583    19.847973     8.365411    98.077804    44.392590
# min      15.000000    11.000000     0.000000     0.400000     0.200000
# 25%      90.000000    70.000000    23.000000    88.300000    37.200000
# 50%     109.000000    85.000000    28.000000   159.900000    67.200000
# 75%     123.000000    96.000000    33.000000   230.600000   100.400000
# max     163.000000   130.000000   226.000000   565.100000   297.600000
#
#            Viscera        Shell        Rings
# count  4177.000000  4177.000000  4177.000000
# mean     36.118722    47.766172     9.933684
# std      21.922850    27.840534     3.224169
# min       0.100000     0.300000     1.000000
# 25%      18.700000    26.000000     8.000000
# 50%      34.200000    46.800000     9.000000
# 75%      50.600000    65.800000    11.000000
# max     152.000000   201.000000    29.000000

# %%
df.isnull().sum()
# Out:
# Sex        0
# Length     0
# Diam       0
# Height     0
# Whole      0
# Shucked    0
# Viscera    0
# Shell      0
# Rings      0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
list(df.columns.values)
# Out:
# ['Sex',
#  'Length',
#  'Diam',
#  'Height',
#  'Whole',
#  'Shucked',
#  'Viscera',
#  'Shell',
#  'Rings']

# %%
df["Length"].plot.box()

# %%
df["Diam"].plot.box()

# %%
df["Height"].plot.box()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
list1=["Sex"]
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#       Sex  Length  Diam  Height  Whole  Shucked  Viscera  Shell  Rings
# 0       2      91    73      19  102.8     44.9     20.2   30.0     15
# 1       2      70    53      18   45.1     19.9      9.7   14.0      7
# 2       0     106    84      27  135.4     51.3     28.3   42.0      9
# 3       2      88    73      25  103.2     43.1     22.8   31.0     10
# 4       1      66    51      16   41.0     17.9      7.9   11.0      7
# 5       1      85    60      19   70.3     28.2     15.5   24.0      8
# 6       0     106    83      30  155.5     47.4     28.3   66.0     20
# 7       0     109    85      25  153.6     58.8     29.9   52.0     16
# 8       2      95    74      25  101.9     43.3     22.5   33.0      9
# 9       0     110    88      30  178.9     62.9     30.2   64.0     19
# 10      0     105    76      28  121.3     38.8     29.5   42.0     14
# 11      2      86    70      22   81.2     33.5     16.2   27.0     10
# 12      2      98    76      27  108.3     43.5     19.0   38.0     11
# 13      0     107    81      29  136.9     54.5     34.2   41.0     10
# 14      0      94    71      20   95.1     33.5     16.1   37.0     10
# 15      2     100    80      26  132.9     51.6     26.6   48.0     12
# 16      1      71    56      17   58.1     19.0      7.9   23.0      7
# 17      0      88    68      20   90.2     37.6     17.4   26.0     10
# 18      2      73    59      16   51.1     19.4      8.6   20.0      7
# 19      2      90    64      20   76.2     34.1     15.0   23.0      9
# 20      2      71    56      19   49.1     19.1     12.4   15.0     11
# 21      1      76    55      20   45.1     16.0      9.8   17.0     10
# 22      0     113    88      31  187.9     85.5     42.8   54.0     12
# 23      0     110    83      27  152.7     63.6     42.0   40.0      9
# 24      0     123    96      33  232.3    102.6     60.2   61.0     10
# 25      0     112    88      28  185.7     76.5     37.6   60.0     11
# 26      0     116    90      37  199.1     78.9     54.4   57.0     11
# 27      2     118    89      28  186.2     71.2     46.8   56.0     12
# 28      2     121    95      36  187.3     78.8     43.8   59.0     15
# 29      2     115    85      28  172.7     78.6     45.4   40.0     11
# ...   ...     ...   ...     ...    ...      ...      ...    ...    ...
# 4147    2     139   110      39  332.9    145.4     72.0   89.0     11
# 4148    2     154   121      35  410.1    160.1    105.2   71.0     11
# 4149    1      56    43      14   24.8     12.6      4.3    6.0      6
# 4150    1      66    46      16   28.0     11.3      7.3    9.2      7
# 4151    1      70    50      15   33.9     16.7      7.1    8.2      6
# 4152    1      74    56      18   43.6     19.9     10.9   12.3      7
# 4153    1      86    63      23   76.8     37.7     14.3   22.0      8
# 4154    1      87    66      19   78.6     43.8     15.0   17.7      6
# 4155    1      88    70      22   76.1     31.5     17.9   23.0      6
# 4156    2      95    74      22   97.9     43.7     21.4   29.2      8
# 4157    2      95    72      28  102.7     48.2     20.9   31.0      8
# 4158    1      96    71      22   89.9     40.2     17.8   28.0      8
# 4159    0     112    88      27  160.5     70.0     32.3   51.8      9
# 4160    0     117    95      33  210.6     91.6     43.4   60.0     11
# 4161    0     117    91      34  198.9     85.1     52.6   56.9     11
# 4162    2      77    51      20   63.5     27.4     13.6   18.4      8
# 4163    1      78    62      17   68.8     36.2     13.9   15.8      7
# 4164    1      78    58      20   56.9     25.1     12.7   16.2      7
# 4165    1      81    60      17   60.7     30.0     10.1   17.6      7
# 4166    1      95    73      23   99.8     46.4     17.7   31.2     10
# 4167    2     100    76      25  115.4     53.8     25.3   30.7      9
# 4168    0     103    80      25  123.0     57.3     24.6   35.3      8
# 4169    2     104    77      33  158.2     75.0     36.0   36.3     10
# 4170    2     110    86      26  167.9     63.1     39.1   48.1     10
# 4171    2     112    86      31  173.5     80.0     34.4   45.8      8
# 4172    0     113    90      33  177.4     74.0     47.8   49.8     11
# 4173    2     118    88      27  193.2     87.8     42.9   52.1     10
# 4174    2     120    95      41  235.2    105.1     57.5   61.6      9
# 4175    0     125    97      30  218.9    106.2     52.2   59.2     10
# 4176    2     142   111      39  389.7    189.1     75.3   99.0     12
#
# [4177 rows x 9 columns]

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.15198011, 0.57455813, 0.43214879, ..., 0.72621157, 0.63821689,
#         1.57154357],
#        [1.15198011, 1.44898585, 1.439929  , ..., 1.20522124, 1.21298732,
#         0.91001299],
#        [1.28068972, 0.05003309, 0.12213032, ..., 0.35668983, 0.20713907,
#         0.28962385],
#        ...,
#        [1.15198011, 0.6329849 , 0.67640943, ..., 0.97541324, 0.49695471,
#         0.28962385],
#        [1.28068972, 0.84118198, 0.77718745, ..., 0.73362741, 0.41073914,
#         0.02057072],
#        [1.15198011, 1.54905203, 1.48263359, ..., 1.78744868, 1.84048058,
#         0.64095986]])

# %%
df=df[(z<3).all(axis=1)]
df.shape
# Out:
# (4027, 9)

# %%
x=df.iloc[:,0:-1].values

# %%
x
# Out:
# array([[  2. ,  91. ,  73. , ...,  44.9,  20.2,  30. ],
#        [  2. ,  70. ,  53. , ...,  19.9,   9.7,  14. ],
#        [  0. , 106. ,  84. , ...,  51.3,  28.3,  42. ],
#        ...,
#        [  2. , 120. ,  95. , ..., 105.1,  57.5,  61.6],
#        [  0. , 125. ,  97. , ..., 106.2,  52.2,  59.2],
#        [  2. , 142. , 111. , ..., 189.1,  75.3,  99. ]])

# %%
x.shape
# Out:
# (4027, 8)

# %%
df["Age"]=df["Rings"]+1.5
df.drop("Rings",axis=1,inplace=True)

# %%
df
# Out:
#       Sex  Length  Diam  Height  Whole  Shucked  Viscera  Shell   Age
# 0       2      91    73      19  102.8     44.9     20.2   30.0  16.5
# 1       2      70    53      18   45.1     19.9      9.7   14.0   8.5
# 2       0     106    84      27  135.4     51.3     28.3   42.0  10.5
# 3       2      88    73      25  103.2     43.1     22.8   31.0  11.5
# 4       1      66    51      16   41.0     17.9      7.9   11.0   8.5
# 5       1      85    60      19   70.3     28.2     15.5   24.0   9.5
# 7       0     109    85      25  153.6     58.8     29.9   52.0  17.5
# 8       2      95    74      25  101.9     43.3     22.5   33.0  10.5
# 9       0     110    88      30  178.9     62.9     30.2   64.0  20.5
# 10      0     105    76      28  121.3     38.8     29.5   42.0  15.5
# 11      2      86    70      22   81.2     33.5     16.2   27.0  11.5
# 12      2      98    76      27  108.3     43.5     19.0   38.0  12.5
# 13      0     107    81      29  136.9     54.5     34.2   41.0  11.5
# 14      0      94    71      20   95.1     33.5     16.1   37.0  11.5
# 15      2     100    80      26  132.9     51.6     26.6   48.0  13.5
# 16      1      71    56      17   58.1     19.0      7.9   23.0   8.5
# 17      0      88    68      20   90.2     37.6     17.4   26.0  11.5
# 18      2      73    59      16   51.1     19.4      8.6   20.0   8.5
# 19      2      90    64      20   76.2     34.1     15.0   23.0  10.5
# 20      2      71    56      19   49.1     19.1     12.4   15.0  12.5
# 21      1      76    55      20   45.1     16.0      9.8   17.0  11.5
# 22      0     113    88      31  187.9     85.5     42.8   54.0  13.5
# 23      0     110    83      27  152.7     63.6     42.0   40.0  10.5
# 24      0     123    96      33  232.3    102.6     60.2   61.0  11.5
# 25      0     112    88      28  185.7     76.5     37.6   60.0  12.5
# 26      0     116    90      37  199.1     78.9     54.4   57.0  12.5
# 27      2     118    89      28  186.2     71.2     46.8   56.0  13.5
# 28      2     121    95      36  187.3     78.8     43.8   59.0  16.5
# 29      2     115    85      28  172.7     78.6     45.4   40.0  12.5
# 30      2     116    94      33  199.5     78.7     48.4   66.0  11.5
# ...   ...     ...   ...     ...    ...      ...      ...    ...   ...
# 4146    2     139   106      42  302.0    132.8     81.9   77.0  11.5
# 4147    2     139   110      39  332.9    145.4     72.0   89.0  12.5
# 4149    1      56    43      14   24.8     12.6      4.3    6.0   7.5
# 4150    1      66    46      16   28.0     11.3      7.3    9.2   8.5
# 4151    1      70    50      15   33.9     16.7      7.1    8.2   7.5
# 4152    1      74    56      18   43.6     19.9     10.9   12.3   8.5
# 4153    1      86    63      23   76.8     37.7     14.3   22.0   9.5
# 4154    1      87    66      19   78.6     43.8     15.0   17.7   7.5
# 4155    1      88    70      22   76.1     31.5     17.9   23.0   7.5
# 4156    2      95    74      22   97.9     43.7     21.4   29.2   9.5
# 4157    2      95    72      28  102.7     48.2     20.9   31.0   9.5
# 4158    1      96    71      22   89.9     40.2     17.8   28.0   9.5
# 4159    0     112    88      27  160.5     70.0     32.3   51.8  10.5
# 4160    0     117    95      33  210.6     91.6     43.4   60.0  12.5
# 4161    0     117    91      34  198.9     85.1     52.6   56.9  12.5
# 4162    2      77    51      20   63.5     27.4     13.6   18.4   9.5
# 4163    1      78    62      17   68.8     36.2     13.9   15.8   8.5
# 4164    1      78    58      20   56.9     25.1     12.7   16.2   8.5
# 4165    1      81    60      17   60.7     30.0     10.1   17.6   8.5
# 4166    1      95    73      23   99.8     46.4     17.7   31.2  11.5
# 4167    2     100    76      25  115.4     53.8     25.3   30.7  10.5
# 4168    0     103    80      25  123.0     57.3     24.6   35.3   9.5
# 4169    2     104    77      33  158.2     75.0     36.0   36.3  11.5
# 4170    2     110    86      26  167.9     63.1     39.1   48.1  11.5
# 4171    2     112    86      31  173.5     80.0     34.4   45.8   9.5
# 4172    0     113    90      33  177.4     74.0     47.8   49.8  12.5
# 4173    2     118    88      27  193.2     87.8     42.9   52.1  11.5
# 4174    2     120    95      41  235.2    105.1     57.5   61.6  10.5
# 4175    0     125    97      30  218.9    106.2     52.2   59.2  11.5
# 4176    2     142   111      39  389.7    189.1     75.3   99.0  13.5
#
# [4027 rows x 9 columns]

# %%
y=df.iloc[:,-1].values

# %%
y=y.reshape(-1,1)

# %%
y.shape
# Out:
# (4027, 1)

# %%
y
# Out:
# array([[16.5],
#        [ 8.5],
#        [10.5],
#        ...,
#        [10.5],
#        [11.5],
#        [13.5]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=45)

# %%
x_train.shape
# Out:
# (2818, 8)

# %%
x_test.shape
# Out:
# (1209, 8)

# %%
y_train.shape
# Out:
# (2818, 1)

# %%
y_test.shape
# Out:
# (1209, 1)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.score(x_train,y_train)
# Out:
# 0.50435620115105

# %%
pred=lm.predict(x_test)

# %%
lm.coef_
# Out:
# array([[ 0.0902964 , -0.00864185,  0.05049281,  0.1262567 ,  0.03539753,
#         -0.08676114, -0.03257033,  0.03694785]])

# %%
lm.intercept_
# Out:
# array([4.27584189])

# %%
from sklearn.metrics import mean_squared_error
print("error:")
print(mean_squared_error(y_test,pred))
# Out:
# error:
# 4.0631283810984735

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.5326484752394559

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso()

# %%
ls.fit(x_train,y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
ls.score(x_train,y_train)
# Out:
# 0.48903639174308944

# %%
ls.coef_
# Out:
# array([ 0.        ,  0.        ,  0.03775798,  0.04065684,  0.02314181,
#        -0.07019547, -0.        ,  0.05282061])

# %%
from sklearn.model_selection import GridSearchCV

# %%
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}

# %%
model=Lasso()
grid=GridSearchCV(estimator=model,param_grid=alphavalue)

# %%
grid.fit(x,y)
# Out:
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=1000, normalize=False, positive=False,
#                              precompute=False, random_state=None,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(grid.best_score_)
# Out:
# 0.4957775848152664

# %%
print(grid.best_params_)
# Out:
# {'alpha': 0}

# %%
t=np.array([[2,70,84,25,80,51.3,28.2,31]])

# %%
t
# Out:
# array([[ 2. , 70. , 84. , 25. , 80. , 51.3, 28.2, 31. ]])

# %%
lm.predict(t)
# Out:
# array([[9.85717456]])

# %%
def linreg():
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    print(lm.score(x_train,y_train))
    print(r2_score(y_test,pred))
    print(mean_squared_error(y_test,pred))

# %%
linreg()
# Out:
# 0.50435620115105
# 0.5326484752394559
# 4.0631283810984735

# %%
from sklearn.externals import joblib
joblib.dump(linreg,"lrsave")
# Out:
# ['lrsave']

# %%
import pickle
s=pickle.dumps(linreg)
clf2=pickle.loads(s)

# %%
clf2
# Out:
# <function __main__.linreg()>
